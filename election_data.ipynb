# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

df = pd.read_table('/Users/jugalmarfatia/Downloads/Bhavnani India State Election Dataset v 3.0.tab')

engine = create_engine('postgresql+psycopg2://jugal1:jugal1@localhost/postgres')

# %%
df.head(20)
# Out:
#            st_name    year  ac_no        ac_name ac_type  \
# 0   Andhra Pradesh  1978.0      1      Ichapuram     GEN
# 1   Andhra Pradesh  1978.0      1      Ichapuram     GEN
# 2   Andhra Pradesh  1978.0      1      Ichapuram     GEN
# 3   Andhra Pradesh  1978.0      1      Ichapuram     GEN
# 4   Andhra Pradesh  1978.0      1      Ichapuram     GEN
# 5   Andhra Pradesh  1978.0      2        Sompeta     GEN
# 6   Andhra Pradesh  1978.0      2        Sompeta     GEN
# 7   Andhra Pradesh  1978.0      2        Sompeta     GEN
# 8   Andhra Pradesh  1978.0      3        Tekkali     GEN
# 9   Andhra Pradesh  1978.0      3        Tekkali     GEN
# 10  Andhra Pradesh  1978.0      3        Tekkali     GEN
# 11  Andhra Pradesh  1978.0      4  Harishchandra     GEN
# 12  Andhra Pradesh  1978.0      4  Harishchandra     GEN
# 13  Andhra Pradesh  1978.0      4  Harishchandra     GEN
# 14  Andhra Pradesh  1978.0      5  Narasannapeta     GEN
# ...

# %%
df.to_sql('indian_election', con=engine, if_exists='replace')

# %%
df_state = pd.read_excel('/Users/jugalmarfatia/Documents/summer2018/RA Work/wage_gap/Wage_Gap/data/state_names.xlsx')
print(df_state)
df_state['GEOLEV1'] = df_state['Code ']
df_state.to_sql('india_state', con=engine, index=False, if_exists='replace', chunksize=100)
# Out:
#      Code                                 State
# 0   356035          Andaman and Nicobar Islands
# 1   356028                       Andhra Pradesh
# 2   356012                    Arunachal Pradesh
# 3   356018                                Assam
# 4   356010                     Bihar, Jharkhand
# 5   356004                           Chandigarh
# 6   356026               Dadra and Nagar Haveli
# 7   356007  National Capital Territory Of Delhi
# 8   356030                   Goa, Daman and Diu
# 9   356024                              Gujarat
# 10  356006                              Haryana
# 11  356002                     Himachal Pradesh
# 12  356001                      Jammu & Kashmir
# 13  356029                            Karnataka
# 14  356032                               Kerala
# 15  356031                          Lakshadweep
# 16  356023         Madhya Pradesh, Chhattisgarh
# 17  356027                          Maharashtra
# 18  356014                              Manipur
# ...

# %%
from tabula import read_pdf

#df_code = read_pdf('/Users/jugalmarfatia/Downloads/geolevel1.pdf', header=2)

# %%
#df_code.iloc[3].to_string()

# %%
#df_code

# %%
df = pd.read_table('/Users/jugalmarfatia/Documents/summer2018/RA Work/wage_gap/Wage_Gap/data/Bhavnani India national election dataset v 2.0.tab')
df.to_sql('india_national_election', con=engine, if_exists='replace')

# %%
df = pd.read_csv('/Users/jugalmarfatia/Documents/summer2018/RA Work/wage_gap/Wage_Gap/data/ipumsi_00004.csv')
# df.to_sql('india_wage', con=engine, if_exists='replace')

# %%
df.head()
# Out:
#    COUNTRY  YEAR     SAMPLE  SERIAL    HHWT  URBAN  REGIONW  GEOLEV1  GEOLEV2  \
# 0      356  1983  356198341    1000  1159.0      1       33   356028      NaN
# 1      356  1983  356198341    1000  1159.0      1       33   356028      NaN
# 2      356  1983  356198341    1000  1159.0      1       33   356028      NaN
# 3      356  1983  356198341    2000  1159.0      1       33   356028      NaN
# 4      356  1983  356198341    2000  1159.0      1       33   356028      NaN
#
#    PERNUM   ...     RELIGIOND  SCHOOL  LIT  EDATTAIN  EDATTAIND  YRSCHOOL  \
# 0       1   ...        3000.0       2    2         3        311      11.0
# 1       2   ...        3000.0       2    2         2        221      10.0
# 2       3   ...        3000.0       1    2         1        120       1.0
# 3       1   ...        3000.0       2    1         1        110       0.0
# 4       2   ...        3000.0       2    1         1        110       0.0
#
#    EMPSTAT  EMPSTATD  LABFORCE  INCWAGE
# ...

# %%
querry_2 = 
''' 
SELECT * 
FROM
(SELECT * from 
    (SELECT st_name
     , year
     , ac_no
     , ac_name
     , cand_name
     , cand_sex
     , totvotpoll
    FROM (SELECT st_name
     , year
     , ac_no
     , ac_name
     , cand_name
     , cand_sex
     , totvotpoll
     , MAX(totvotpoll) OVER (PARTITION BY st_name, year, ac_no) max_totvotpoll
      FROM indian_election) as a
 WHERE totvotpoll = max_totvotpoll) as election
 JOIN india_state 
    ON  election.st_name = india_state."State") as a
 JOIN "public"."india_wage"
    ON a."Code " =  "india_wage"."GEOLEV1";'''

top_states_df = pd.read_sql(querry_2, engine)
top_states_df.head(10)
